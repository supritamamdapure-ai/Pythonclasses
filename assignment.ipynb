# %%
print("Hello, Python!")
print("This", end=" ")
print("is")
print("my", "first", sep=" ")
print("assignment.")
# Out:
# Hello, Python!
# This is
# my first
# assignment.

# %%
print("Name: Suprita Mamdapure", end="\t")
print("Age: 27", end="\t")
print("City: Bangalore")
# Out:
# Name: Suprita Mamdapure	Age: 27	City: Bangalore

# %%
product_name = "Laptop"
quantity = 3
unit_price = 10000
total_cost = quantity*unit_price

print(f"Product:{product_name}")
print(f"Quantity: {quantity}")
print(f"Unit Price: {unit_price}")
print(f"Total cost: {total_cost}")
# Out:
# Product:Laptop
# Quantity: 3
# Unit Price: 10000
# Total cost: 30000

# %%
first_name = input ("First Name:")
last_name = input("Last Name:")
birth_year = int(input("Birth Year:"))
current_year = int(input("Current Year:"))

age = current_year - birth_year
print(f"Hello, {first_name}, {last_name}! You are approximately {age} years old.")
# Out:
# Hello, John, Doe! You are approximately 25 years old.

# %%
a=5
b=6
sum = a+b
diff= a-b
product= a*b
quotient = a/b

print("Sum:",sum )
print("Difference:", diff)
print("Product:", product)
print("Quotient:", round(quotient,2))
# Out:
# Sum: 11
# Difference: -1
# Product: 30
# Quotient: 0.83

# %%
# Store two numbers
a = 10
b = 20

# Calculate their sum
c = a + b

# Print the sum
print(c)

# Store greeting words
d = "Hello"
e = "Python"

# Combine the strings with a space
f=d + " " + e

# Print the final message
print(f)
# Out:
# 30
# Hello Python
